# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from Functions import Basic_info_func
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from scipy import stats

# %%
df = pd.read_csv('./Data/train.csv')

# %%
Basic_info_func(df)
# Out:
#                                  Missing_values  N_uniques Data_type  \
# Feature
# number_of_elements                            0          9     int64
# mean_atomic_mass                              0       3365   float64
# wtd_mean_atomic_mass                          0      15164   float64
# gmean_atomic_mass                             0       3365   float64
# wtd_gmean_atomic_mass                         0      15165   float64
# entropy_atomic_mass                           0       3314   float64
# wtd_entropy_atomic_mass                       0      15113   float64
# range_atomic_mass                             0       1042   float64
# wtd_range_atomic_mass                         0      12641   float64
# std_atomic_mass                               0       3313   float64
# wtd_std_atomic_mass                           0      15031   float64
# mean_fie                                      0       2997   float64
# wtd_mean_fie                                  0      14940   float64
# gmean_fie                                     0       3286   float64
# wtd_gmean_fie                                 0      15089   float64
# entropy_fie                                   0       3238   float64
# wtd_entropy_fie                               0      15058   float64
# range_fie                                     0        854   float64
# wtd_range_fie                                 0      12266   float64
# std_fie                                       0       3185   float64
# wtd_std_fie                                   0      14922   float64
# mean_atomic_radius                            0        942   float64
# wtd_mean_atomic_radius                        0      12423   float64
# gmean_atomic_radius                           0       3148   float64
# wtd_gmean_atomic_radius                       0      14969   float64
# entropy_atomic_radius                         0       3111   float64
# wtd_entropy_atomic_radius                     0      14948   float64
# range_atomic_radius                           0        195     int64
# wtd_range_atomic_radius                       0      11407   float64
# std_atomic_radius                             0       2529   float64
# wtd_std_atomic_radius                         0      14312   float64
# mean_Density                                  0       3274   float64
# wtd_mean_Density                              0      15010   float64
# gmean_Density                                 0       3332   float64
# wtd_gmean_Density                             0      15085   float64
# entropy_Density                               0       3283   float64
# wtd_entropy_Density                           0      15087   float64
# range_Density                                 0        890   float64
# wtd_range_Density                             0       9279   float64
# std_Density                                   0       3265   float64
# wtd_std_Density                               0      14939   float64
# mean_ElectronAffinity                         0       2377   float64
# wtd_mean_ElectronAffinity                     0      13526   float64
# gmean_ElectronAffinity                        0       2678   float64
# wtd_gmean_ElectronAffinity                    0      13752   float64
# entropy_ElectronAffinity                      0       2635   float64
# wtd_entropy_ElectronAffinity                  0      14078   float64
# range_ElectronAffinity                        0        644   float64
# wtd_range_ElectronAffinity                    0      10937   float64
# std_ElectronAffinity                          0       2562   float64
# wtd_std_ElectronAffinity                      0      13581   float64
# mean_FusionHeat                               0       2660   float64
# wtd_mean_FusionHeat                           0      14194   float64
# gmean_FusionHeat                              0       3166   float64
# wtd_gmean_FusionHeat                          0      14767   float64
# entropy_FusionHeat                            0       3108   float64
# wtd_entropy_FusionHeat                        0      14885   float64
# range_FusionHeat                              0        595   float64
# wtd_range_FusionHeat                          0       9671   float64
# std_FusionHeat                                0       2920   float64
# wtd_std_FusionHeat                            0      14470   float64
# mean_ThermalConductivity                      0       1980   float64
# wtd_mean_ThermalConductivity                  0      13150   float64
# gmean_ThermalConductivity                     0       2737   float64
# wtd_gmean_ThermalConductivity                 0      14152   float64
# entropy_ThermalConductivity                   0       2711   float64
# wtd_entropy_ThermalConductivity               0      14269   float64
# range_ThermalConductivity                     0        452   float64
# wtd_range_ThermalConductivity                 0       7996   float64
# std_ThermalConductivity                       0       2492   float64
# wtd_std_ThermalConductivity                   0      13797   float64
# mean_Valence                                  0         63   float64
# wtd_mean_Valence                              0       5737   float64
# gmean_Valence                                 0        243   float64
# wtd_gmean_Valence                             0       8102   float64
# entropy_Valence                               0        319   float64
# wtd_entropy_Valence                           0      10778   float64
# range_Valence                                 0          7     int64
# wtd_range_Valence                             0       5908   float64
# std_Valence                                   0        125   float64
# wtd_std_Valence                               0       7082   float64
# critical_temp                                 0       3007   float64
#
#                                  missing_percentage
# Feature
# number_of_elements                                0
# mean_atomic_mass                                  0
# wtd_mean_atomic_mass                              0
# gmean_atomic_mass                                 0
# wtd_gmean_atomic_mass                             0
# entropy_atomic_mass                               0
# wtd_entropy_atomic_mass                           0
# range_atomic_mass                                 0
# wtd_range_atomic_mass                             0
# std_atomic_mass                                   0
# wtd_std_atomic_mass                               0
# mean_fie                                          0
# wtd_mean_fie                                      0
# gmean_fie                                         0
# wtd_gmean_fie                                     0
# entropy_fie                                       0
# wtd_entropy_fie                                   0
# range_fie                                         0
# wtd_range_fie                                     0
# std_fie                                           0
# wtd_std_fie                                       0
# mean_atomic_radius                                0
# wtd_mean_atomic_radius                            0
# gmean_atomic_radius                               0
# wtd_gmean_atomic_radius                           0
# entropy_atomic_radius                             0
# wtd_entropy_atomic_radius                         0
# range_atomic_radius                               0
# wtd_range_atomic_radius                           0
# std_atomic_radius                                 0
# wtd_std_atomic_radius                             0
# mean_Density                                      0
# wtd_mean_Density                                  0
# gmean_Density                                     0
# wtd_gmean_Density                                 0
# entropy_Density                                   0
# wtd_entropy_Density                               0
# range_Density                                     0
# wtd_range_Density                                 0
# std_Density                                       0
# wtd_std_Density                                   0
# mean_ElectronAffinity                             0
# wtd_mean_ElectronAffinity                         0
# gmean_ElectronAffinity                            0
# wtd_gmean_ElectronAffinity                        0
# entropy_ElectronAffinity                          0
# wtd_entropy_ElectronAffinity                      0
# range_ElectronAffinity                            0
# wtd_range_ElectronAffinity                        0
# std_ElectronAffinity                              0
# wtd_std_ElectronAffinity                          0
# mean_FusionHeat                                   0
# wtd_mean_FusionHeat                               0
# gmean_FusionHeat                                  0
# wtd_gmean_FusionHeat                              0
# entropy_FusionHeat                                0
# wtd_entropy_FusionHeat                            0
# range_FusionHeat                                  0
# wtd_range_FusionHeat                              0
# std_FusionHeat                                    0
# wtd_std_FusionHeat                                0
# mean_ThermalConductivity                          0
# wtd_mean_ThermalConductivity                      0
# gmean_ThermalConductivity                         0
# wtd_gmean_ThermalConductivity                     0
# entropy_ThermalConductivity                       0
# wtd_entropy_ThermalConductivity                   0
# range_ThermalConductivity                         0
# wtd_range_ThermalConductivity                     0
# std_ThermalConductivity                           0
# wtd_std_ThermalConductivity                       0
# mean_Valence                                      0
# wtd_mean_Valence                                  0
# gmean_Valence                                     0
# wtd_gmean_Valence                                 0
# entropy_Valence                                   0
# wtd_entropy_Valence                               0
# range_Valence                                     0
# wtd_range_Valence                                 0
# std_Valence                                       0
# wtd_std_Valence                                   0
# critical_temp                                     0

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21263.000000      21263.000000          21263.000000
# mean             4.115224         87.557631             72.988310
# std              1.439295         29.676497             33.490406
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.143839
# 50%              4.000000         84.922750             60.696571
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21263.000000           21263.000000         21263.000000
# mean           71.290627              58.539916             1.165608
# std            31.030272              36.651067             0.364930
# min             5.320573               1.960849             0.000000
# 25%            58.041225              35.248990             0.966676
# 50%            66.361592              39.918385             1.199541
# 75%            78.116681              73.113234             1.444537
# max           208.980400             208.980400             1.983797
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# count             21263.000000       21263.000000           21263.000000
# mean                  1.063884         115.601251              33.225218
# std                   0.401423          54.626887              26.967752
# min                   0.000000           0.000000               0.000000
# 25%                   0.775363          78.512902              16.824174
# 50%                   1.146783         122.906070              26.636008
# 75%                   1.359418         154.119320              38.356908
# max                   1.958203         207.972460             205.589910
#
#        std_atomic_mass  wtd_std_atomic_mass      mean_fie  wtd_mean_fie  \
# count     21263.000000         21263.000000  21263.000000  21263.000000
# mean         44.391893            41.448045    769.614748    870.442317
# std          20.035430            19.983544     87.488694    143.278200
# min           0.000000             0.000000    375.500000    375.500000
# 25%          32.890369            28.539377    723.740000    738.946339
# 50%          45.123500            44.285984    764.900000    889.966667
# 75%          59.322812            53.629284    796.320000   1004.117384
# max         101.019700           101.019700   1313.100000   1348.028986
#
#           gmean_fie  wtd_gmean_fie   entropy_fie  wtd_entropy_fie  \
# count  21263.000000   21263.000000  21263.000000     21263.000000
# mean     737.474751     832.769649      1.299172         0.926726
# std       78.327275     119.772520      0.381935         0.334018
# min      375.500000     375.500000      0.000000         0.000000
# 25%      692.541331     720.108284      1.085871         0.753757
# 50%      727.960610     856.202765      1.356236         0.916843
# 75%      765.715174     937.575826      1.551120         1.061750
# max     1313.100000    1327.593381      2.157777         2.038560
#
#           range_fie  wtd_range_fie       std_fie   wtd_std_fie  \
# count  21263.000000   21263.000000  21263.000000  21263.000000
# mean     572.222612     483.517264    215.631279    224.050033
# std      309.614442     224.042874    109.966774    127.927104
# min        0.000000       0.000000      0.000000      0.000000
# 25%      262.400000     291.088889    114.135763     92.994286
# 50%      764.100000     510.440000    266.373871    258.449503
# 75%      810.600000     690.703310    297.724924    342.656991
# max     1304.500000    1251.855072    499.671949    479.162305
#
#        mean_atomic_radius  wtd_mean_atomic_radius  gmean_atomic_radius  \
# count        21263.000000            21263.000000         21263.000000
# mean           157.983101              134.720039           144.448738
# std             20.147288               28.801567            22.090958
# min             48.000000               48.000000            48.000000
# 25%            149.333333              112.127359           133.542493
# 50%            160.250000              125.970297           142.807563
# 75%            169.857143              158.265231           155.938199
# max            298.000000              298.000000           298.000000
#
#        wtd_gmean_atomic_radius  entropy_atomic_radius  \
# count             21263.000000           21263.000000
# mean                120.989330               1.267756
# std                  35.837843               0.375411
# min                  48.000000               0.000000
# 25%                  89.210097               1.066389
# 50%                 113.181369               1.330735
# 75%                 150.988640               1.512348
# max                 298.000000               2.141961
#
#        wtd_entropy_atomic_radius  range_atomic_radius  \
# count               21263.000000         21263.000000
# mean                    1.131138           139.325025
# std                     0.407159            67.272228
# min                     0.000000             0.000000
# 25%                     0.852181            80.000000
# 50%                     1.242878           171.000000
# 75%                     1.425684           205.000000
# max                     1.903748           256.000000
#
#        wtd_range_atomic_radius  std_atomic_radius  wtd_std_atomic_radius  \
# count             21263.000000       21263.000000           21263.000000
# mean                 51.369885          51.601267              52.340465
# std                  35.019356          22.898396              25.294524
# min                   0.000000           0.000000               0.000000
# 25%                  28.598137          35.112518              32.016958
# 50%                  43.000000          58.663106              59.932929
# 75%                  60.224491          69.424491              73.777278
# max                 240.164344         115.500000              97.140711
#
#        mean_Density  wtd_mean_Density  gmean_Density  wtd_gmean_Density  \
# count  21263.000000      21263.000000   21263.000000       21263.000000
# mean    6111.465214       5267.188547    3460.692235        3117.241110
# std     2846.785185       3221.314506    3703.256370        3975.122587
# min        1.429000          1.429000       1.429000           0.686245
# 25%     4513.500000       2999.158291     883.117278          66.746836
# 50%     5329.085800       4303.421500    1339.974702        1515.364631
# 75%     6728.000000       6416.333333    5794.965188        5766.015191
# max    22590.000000      22590.000000   22590.000000       22590.000000
#
#        entropy_Density  wtd_entropy_Density  range_Density  wtd_range_Density  \
# count     21263.000000         21263.000000   21263.000000       21263.000000
# mean          1.072425             0.856037    8665.438818        2902.736814
# std           0.342356             0.319761    4097.126831        2398.471020
# min           0.000000             0.000000       0.000000           0.000000
# 25%           0.913959             0.688693    6648.000000        1656.847429
# 50%           1.090610             0.882747    8958.571000        2082.956581
# 75%           1.323930             1.080939    9778.571000        3409.026316
# max           1.954297             1.703420   22588.571000       22434.160000
#
#         std_Density  wtd_std_Density  mean_ElectronAffinity  \
# count  21263.000000     21263.000000           21263.000000
# mean    3416.910784      3319.170628              76.879751
# std     1673.624915      1611.799629              27.701890
# min        0.000000         0.000000               1.500000
# 25%     2819.497063      2564.342926              62.090000
# 50%     3301.890502      3625.631828              73.100000
# 75%     4004.273231      3959.191394              85.504167
# max    10724.374500     10410.932005             326.100000
#
#        wtd_mean_ElectronAffinity  gmean_ElectronAffinity  \
# count               21263.000000            21263.000000
# mean                   92.717486               54.359502
# std                    32.276387               29.007425
# min                     1.500000                1.500000
# 25%                    73.350000               33.700512
# 50%                   102.856863               51.470113
# 75%                   110.738462               67.505900
# max                   326.100000              326.100000
#
#        wtd_gmean_ElectronAffinity  entropy_ElectronAffinity  \
# count                21263.000000              21263.000000
# mean                    72.416225                  1.070250
# std                     31.648444                  0.343391
# min                      1.500000                  0.000000
# 25%                     50.772124                  0.890589
# 50%                     73.173958                  1.138284
# 75%                     89.975670                  1.345894
# max                    326.100000                  1.767732
#
#        wtd_entropy_ElectronAffinity  range_ElectronAffinity  \
# count                  21263.000000            21263.000000
# mean                       0.770757              120.730514
# std                        0.285986               58.700327
# min                        0.000000                0.000000
# 25%                        0.660662               86.700000
# 50%                        0.781205              127.050000
# 75%                        0.877541              138.630000
# max                        1.675400              349.000000
#
#        wtd_range_ElectronAffinity  std_ElectronAffinity  \
# count                21263.000000          21263.000000
# mean                    59.332637             48.912207
# std                     28.620409             21.740521
# min                      0.000000              0.000000
# 25%                     34.036000             38.372410
# 50%                     71.156250             51.125720
# 75%                     76.706965             56.221787
# max                    218.696600            162.895331
#
#        wtd_std_ElectronAffinity  mean_FusionHeat  wtd_mean_FusionHeat  \
# count              21263.000000     21263.000000         21263.000000
# mean                  44.409356        14.296113            13.848001
# std                   20.429293        11.300188            14.279335
# min                    0.000000         0.222000             0.222000
# 25%                   33.440123         7.588667             5.033407
# 50%                   48.029866         9.304400             8.330667
# 75%                   53.320838        17.114444            18.514286
# max                  169.075862       105.000000           105.000000
#
#        gmean_FusionHeat  wtd_gmean_FusionHeat  entropy_FusionHeat  \
# count      21263.000000          21263.000000        21263.000000
# mean          10.136977             10.141161            1.093343
# std           10.065901             13.134007            0.375932
# min            0.222000              0.222000            0.000000
# 25%            4.109978              1.322127            0.833333
# 50%            5.253498              4.929787            1.112098
# 75%           13.600037             16.428652            1.378110
# max          105.000000            105.000000            2.034410
#
#        wtd_entropy_FusionHeat  range_FusionHeat  wtd_range_FusionHeat  \
# count            21263.000000      21263.000000          21263.000000
# mean                 0.914065         21.138994              8.218528
# std                  0.370125         20.370620             11.414066
# min                  0.000000          0.000000              0.000000
# 25%                  0.672732         12.878000              2.329309
# 50%                  0.994998         12.878000              3.436400
# 75%                  1.157379         23.200000             10.498780
# max                  1.747165        104.778000            102.675000
#
#        std_FusionHeat  wtd_std_FusionHeat  mean_ThermalConductivity  \
# count    21263.000000        21263.000000              21263.000000
# mean         8.323333            7.717576                 89.706911
# std          8.671651            7.288239                 38.517485
# min          0.000000            0.000000                  0.026580
# 25%          4.261340            4.603491                 61.000000
# 50%          4.948155            5.500675                 96.504430
# 75%          9.041230            8.017581                111.005316
# max         51.635000           51.680482                332.500000
#
#        wtd_mean_ThermalConductivity  gmean_ThermalConductivity  \
# count                  21263.000000               21263.000000
# mean                      81.549080                  29.841727
# std                       45.519256                  34.059581
# min                        0.026580                   0.026580
# 25%                       54.180953                   8.339818
# 50%                       73.333333                  14.287643
# 75%                       99.062911                  42.371302
# max                      406.960000                 317.883627
#
#        wtd_gmean_ThermalConductivity  entropy_ThermalConductivity  \
# count                   21263.000000                 21263.000000
# mean                       27.308061                     0.727630
# std                        40.191150                     0.325976
# min                         0.022952                     0.000000
# 25%                         1.087284                     0.457810
# 50%                         6.096120                     0.738694
# 75%                        47.308041                     0.962218
# max                       376.032878                     1.633977
#
#        wtd_entropy_ThermalConductivity  range_ThermalConductivity  \
# count                     21263.000000               21263.000000
# mean                          0.539991                 250.893443
# std                           0.318248                 158.703557
# min                           0.000000                   0.000000
# 25%                           0.250677                  86.382000
# 50%                           0.545783                 399.795000
# 75%                           0.777353                 399.973420
# max                           1.612989                 429.974170
#
#        wtd_range_ThermalConductivity  std_ThermalConductivity  \
# count                   21263.000000             21263.000000
# mean                       62.033066                98.943993
# std                        43.123317                60.143272
# min                         0.000000                 0.000000
# 25%                        29.349419                37.933172
# 50%                        56.556240               135.762089
# 75%                        91.869245               153.806272
# max                       401.440000               214.986150
#
#        wtd_std_ThermalConductivity  mean_Valence  wtd_mean_Valence  \
# count                 21263.000000  21263.000000      21263.000000
# mean                     96.234051      3.198228          3.153127
# std                      63.710355      1.044611          1.191249
# min                       0.000000      1.000000          1.000000
# 25%                      31.985437      2.333333          2.116732
# 50%                     113.556983      2.833333          2.618182
# 75%                     162.711144      4.000000          4.026201
# max                     213.300452      7.000000          7.000000
#
#        gmean_Valence  wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  \
# count   21263.000000       21263.000000     21263.000000         21263.000000
# mean        3.056536           3.055885         1.295682             1.052841
# std         1.046257           1.174815         0.393155             0.380291
# min         1.000000           1.000000         0.000000             0.000000
# 25%         2.279705           2.091251         1.060857             0.775678
# 50%         2.615321           2.434057         1.368922             1.166532
# 75%         3.727919           3.914868         1.589027             1.330801
# max         7.000000           7.000000         2.141963             1.949739
#
#        range_Valence  wtd_range_Valence   std_Valence  wtd_std_Valence  \
# count   21263.000000       21263.000000  21263.000000     21263.000000
# mean        2.041010           1.483007      0.839342         0.673987
# std         1.242345           0.978176      0.484676         0.455580
# min         0.000000           0.000000      0.000000         0.000000
# 25%         1.000000           0.921454      0.451754         0.306892
# 50%         2.000000           1.063077      0.800000         0.500000
# 75%         3.000000           1.918400      1.200000         1.020436
# max         6.000000           6.992200      3.000000         3.000000
#
#        critical_temp
# count   21263.000000
# mean       34.421219
# std        34.254362
# min         0.000210
# 25%         5.365000
# 50%        20.000000
# 75%        63.000000
# max       185.000000

# %% [markdown]
# ## EDA

# %%
# Create the subplots
sns.set_style('darkgrid')
fig, ax = plt.subplots(2, 2, figsize=(10, 6), dpi = 300)

# Histogram
sns.histplot(data=df, x='critical_temp', kde=True, ax=ax[0, 0], edgecolor= 'black')
ax[0, 0].set_title('Histogram with KDE')

# Box plot
sns.boxplot(data=df, x='critical_temp', ax=ax[0, 1])
ax[0, 1].set_title('Box Plot')

# KDE plot
sns.kdeplot(data=df, x='critical_temp', ax=ax[1, 0], fill= True)
ax[1, 1].set_title('KDE Plot')


# Calculate the five-number summary
five_number_summary = np.percentile(df['critical_temp'], [0, 25, 50, 75, 100])

# Add table for five-number summary to the fourth subplot
ax[1, 1].axis('off')  # Hide the axis

# Create the table and add it to the subplot
table_data = [['Min', five_number_summary[0]],
              ['Q1', five_number_summary[1]],
              ['Median', five_number_summary[2]],
              ['Q3', five_number_summary[3]],
              ['Max', five_number_summary[4]],
              ['Std', round(np.std(df['critical_temp']), 4)]]

# Create the table and add it to the subplot
table = ax[1, 1].table(cellText=table_data, colLabels=['Statistic', 'Value'], loc='center', cellLoc='center')

# Adjust the table properties
table.auto_set_font_size(False)
table.set_fontsize(15)
table.scale(0.8, 1.5)

# Set the title for the subplot with the table
ax[1, 1].set_title('Five-Number Summary')

plt.tight_layout()
plt.show()
